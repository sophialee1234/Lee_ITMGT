# %% [markdown]
# # Recommender System based on Artist Collaboration
# - This system suggests new music and artists to users by analyzing data on past collaborations. Through identifying connections, the system will make recommendations that align with the user’s tastes.
#
# ***Objective:*** To introduce the user to new favorite artists, uncover hidden musical gems, and foster a more interconnected listening experience💎
#
# ***Dataset Used:*** https://www.kaggle.com/datasets/ambaliyagati/spotify-dataset-for-playing-around-with-sql/code
#
# ***Input:*** User's artist👩‍🎤
#
# ***Output:*** A dataframe containing the names of artist collaborators👥, how many times they collaborated🖐️,
# for what albums and songs💿

# %% [markdown]
# ## _________________________________________________________________________________________

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\leeso\Downloads\Spotify_kaggle_dataset.csv")
# df = pd.read_csv("spotify_tracks.csv")
df
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
#             genre                                     artists  \
# 0        acoustic                               Billy Raffoul
# 1        acoustic                               Billy Raffoul
# 2        acoustic               Molly Hocking, Bailey Rushlow
# 3        acoustic                           The Goo Goo Dolls
# 4        acoustic               Guus Dielissen, Casper Esmann
# ...           ...                                         ...
# 6295  world-music                          Future World Music
# 6296  world-music  Putumayo, Marianne Perrudin, Thomas Artaud
# 6297  world-music                             Joseph Tawadros
# 6298  world-music                          Future World Music
# 6299  world-music                  Putumayo, Giacomo Lariccia
#
#                                               album  popularity  duration_ms  \
# 0                                              1975          58       172199
# 1                           A Few More Hours at YYZ          57       172202
# 2                     Here Comes the Sun (Acoustic)          42       144786
# 3                                 Dizzy up the Girl          46       116573
# 4     My Love Mine All Mine (Acoustic Instrumental)          33       133922
# ...                                             ...         ...          ...
# 6295                             Reign of Vengeance          25       180001
# 6296                  Global Relaxation by Putumayo          25       276776
# 6297                                    World Music          12        69533
# 6298                                         Behold          26        90001
# 6299                      World Party 5 by Putumayo          25       141800
#
#       explicit
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 6295     False
# 6296     False
# 6297     False
# 6298     False
# 6299     False
#
# [6300 rows x 8 columns]

# %% [markdown]
# ## Initial Processing ------------------------

# %%
print(df['id'].value_counts())
print(df['name'].value_counts())
# Out:
# id
# 1OG1NoKpZZLrMqMYCk9m84    3
# 4uOBL4DDWWVx4RhYKlPbPC    3
# 2cqxvn34ihH7BSv9XbkOgq    3
# 190l7oYBQe6JBsWPJM2uNN    2
# 28zSrc22pN7CSv01aKVxvg    2
#                          ..
# 7qpbYhyFEv6e6dDhPyDKYZ    1
# 63FWYiuggXZPsiNae0L9cd    1
# 5ct1TZKCnSxyDzUxhgLcAq    1
# 0fW7wX2goqLrMCjkxP7873    1
# 3ry0f8ybk8upUBIk8unvmF    1
# Name: count, Length: 6187, dtype: int64
# name
# Kids                           26
# Movies                         26
# Chill                          23
# Romance                        23
# Road Trip                      23
#                                ..
# The Grave Awaits                1
# Punishment                      1
# We Hate Grindcore               1
# The Protocols Of Anti-Sound     1
# Fiore d'inverno                 1
# Name: count, Length: 4518, dtype: int64

# %%
# Both the "id" and "name" columns contain non-unique values.
# Given the difference in number of repetitions, we can use "id" as the song reference.

# %%
# Check ID replicates
df[df['id'] == '1OG1NoKpZZLrMqMYCk9m84']
# Out:
#                           id      name  genre     artists      album  \
# 3221  1OG1NoKpZZLrMqMYCk9m84  LALALALA  j-pop  Stray Kids  ROCK-STAR
# 3360  1OG1NoKpZZLrMqMYCk9m84  LALALALA  k-pop  Stray Kids  ROCK-STAR
# 3449  1OG1NoKpZZLrMqMYCk9m84  LALALALA   kids  Stray Kids  ROCK-STAR
#
#       popularity  duration_ms  explicit
# 3221          73       182224     False
# 3360          73       182224     False
# 3449          73       182224     False

# %%
# Create a new DataFrame, all with unique id values

unique_id_df = df.copy()
unique_id_df.drop_duplicates(subset='id', keep = 'first', inplace=True, ignore_index=True)
unique_id_df.head()
# Out:
#                        id                                           name  \
# 0  7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1  1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2  6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3  1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4  5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
#
#       genre                        artists  \
# 0  acoustic                  Billy Raffoul
# 1  acoustic                  Billy Raffoul
# 2  acoustic  Molly Hocking, Bailey Rushlow
# 3  acoustic              The Goo Goo Dolls
# 4  acoustic  Guus Dielissen, Casper Esmann
#
#                                            album  popularity  duration_ms  \
# 0                                           1975          58       172199
# 1                        A Few More Hours at YYZ          57       172202
# 2                  Here Comes the Sun (Acoustic)          42       144786
# 3                              Dizzy up the Girl          46       116573
# 4  My Love Mine All Mine (Acoustic Instrumental)          33       133922
#
#    explicit
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# Comparison

print(len(df))
print(len(unique_id_df))
# Out:
# 6300
# 6187

# %% [markdown]
# ## Data Manipulation ------------------------

# %%
# Create a list containing every artist

unique_artist_list = []
for i in range(len(unique_id_df)):
    artist_list = []
    entry = df.loc[i]["artists"]
    if "," in entry:
        artist_list = entry.split(",")
    else:
        artist_list.append(entry)
    for artist in artist_list:
        if artist in unique_artist_list:
            continue
        else:
            unique_artist_list.append(artist)

unique_artist_list
# Out:
# ['Billy Raffoul',
#  'Molly Hocking',
#  ' Bailey Rushlow',
#  'The Goo Goo Dolls',
#  'Guus Dielissen',
#  ' Casper Esmann',
#  'Ling tosite sigure',
#  'Benson Boone',
#  ' Andrew Gialanella',
#  'Sonido de Agua en Bambu',
#  'Healing Solfeggio Frequencies',
#  ' Harmony Touch',
#  'Roses & Frey',
#  'The Re-Stoned',
#  'Sam Smith',
#  'The Moon Loungers',
#  'Lesfm',
#  ' Olexy',
#  'SLANDER',
#  ' Dylan Matthew',
#  'Cody Fry',
#  'Mortal Treason',
#  'Frank Ocean',
#  'Girl in the Distance',
#  'Simon & Garfunkel',
#  'Jonah Baker',
#  'Puppe Music',
#  'SYML',
#  'Acoustic Levitation',
#  'Trainman',
#  'Hillside Recording',
#  ' Diana Trout',
#  'Acoustics',
#  ' Tyler Swatie',
#  'Kondor',
#  'Jason Derulo',
#  'Acoustic Quarter',
#  'Helios Jazz Club',
#  'AJR',
#  'Devin The Dude',
#  'Ben Weighill',
#  'David AI',
#  'SZA',
#  ' Justin Bieber',
#  'Jay Filson',
#  'U Know & The Drill',
#  'Matt Johnson',
#  ' John Adams',
#  'XtraVert',
#  'Bailey Zimmerman',
#  'Thomas Daniel',
#  'Mark S.D.Ray',
#  'Noah Kahan',
#  'Acoustic Guitar Collective',
#  'Dj funkybee',
#  'Lofi Afrobeats',
#  ' Dj Discoteca',
#  ' AfrooBeatZ',
#  ' Dj AfroBeats',
#  ' Afro Beat Music',
#  'Davido',
#  ' Musa Keys',
#  'Gbenga',
#  'Giuliano Nicolis',
#  'Asake',
#  'FASSounds',
#  'Karl Lion',
#  'Victony',
#  ' Tempoe',
#  'Jujuba',
#  'Osocity',
#  'Omah Lay',
#  'Entspannungsmusik Meer',
#  'Rema',
#  'Bür Gür',
#  'Robert Glasper',
#  ' Derrick Hodge',
#  'AfroBeats',
#  'Paul CleverLee',
#  'Wizkid',
#  ' Ayra Starr',
#  'Negus Beauvoir',
#  'MC Neneco',
#  ' DJ Netto',
#  ' MC Chara',
#  ' MC GIBI',
#  ' Asake',
#  'Royalty Free Music Background',
#  ' AfroBeatsZ',
#  'African Tribal Orchestra',
#  'Jordan Films RD',
#  ' Wande Coal',
#  'Oneness Of Juju',
#  ' Russ',
#  'Ruankkj',
#  'Simon Le Grec',
#  'DJ Pasta',
#  ' Brucaliff',
#  'Adekunle Gold',
#  'Marlon Dasoul',
#  'Diomobeats',
#  'Ayra Starr',
#  'Dualbox',
#  ' Aracy Carvalho',
#  'Luigi Vitale',
#  ' Gianpaolo Rinaldi',
#  ' Luca Colussi',
#  " Daniele D'Agaro",
#  ' Mirko Cisilino',
#  ' Denis Biason',
#  'Don & Gene',
#  'Dani Le Cross',
#  'Eudo 97',
#  'Rehab',
#  'alt-J',
#  'The Incomplete Orchestra',
#  'Jack Curtis Dubowsky',
#  'Psalms Remixed',
#  'AWOLNATION',
#  'Atlanta Rhythm Section',
#  'Alton Ellis',
#  ' The Flames',
#  'Milmine',
#  'Midland',
#  'Red',
#  'Pritam',
#  ' Arijit Singh',
#  ' Shreya Ghoshal',
#  ' Shadab Faridi',
#  ' Altamash Faridi',
#  ' Amitabh Bhattacharya',
#  'Smile Empty Soul',
#  'ALT BLK ERA',
#  'Uncle Morty and the Empty Forties',
#  'LUCKI',
#  'Anarchist Sanctuary',
#  ' asteria',
#  'Led Zeppelin',
#  'The Exies',
#  'HOYO-MiX',
#  ' 王可鑫',
#  'Ra',
#  'All Time Low',
#  'Alter Ego',
#  'tiedye ky',
#  'Buddy Holly',
#  '311',
#  'Bill Haley & His Comets',
#  'alt.',
#  'Stiff Little Fingers',
#  'Lyn Lapid',
#  'RØRY',
#  'Apel8',
#  'Reel Big Fish',
#  'Spose',
#  'Barenaked Ladies',
#  'The Exploited',
#  'Zeph',
#  'Lofi Bee',
#  ' Ogi Feel the Beat',
#  ' Chill Select',
#  'Meditation Music Zone',
#  ' Mindfulness Meditation Music Spa Maestro',
#  ' Meditação e Espiritualidade Musica Academia',
#  'Sierra Ferrell',
#  'Liza',
#  'ぬいぐるみクレヨン Lush Crayon',
#  'Chloe Ament',
#  '"Weird Al" Yankovic',
#  'Cowboy Mouth',
#  'Will Wood',
#  'Ambriosa Flame',
#  'Sarah Fortwo',
#  'Layto',
#  'Decanõe',
#  'Broadway Homestuck',
#  'APOCALIPSIS',
#  'The Skyliners',
#  'Alter.',
#  'Brian Eno',
#  'Brendan Benson',
#  'Rebelion',
#  ' Sub Sonik',
#  ' LXCPR',
#  'Feverkin',
#  'The Modern Lovers',
#  'Alternative Radio',
#  'Thousand Foot Krutch',
#  'Cusp',
#  'The Alternate Routes',
#  'MoonDeity',
#  ' Phonk Killer',
#  'David Bowie',
#  'No Hotel',
#  'Vance Joy',
#  'Lissom',
#  ' Julien Marchal',
#  ' Lowswimmer',
#  'J Balvin',
#  'Hovar',
#  'Rangitoto',
#  'Sound Xscape',
#  'chill phil',
#  "Avery's Ambient",
#  'Rayne',
#  'Ambient Eclipse',
#  'Kilometre Club',
#  'ERS Lofi',
#  'A Deeper Sense',
#  'Spoofi',
#  'Suburban DZ',
#  'Moonlynx',
#  'AIArt Electronics',
#  'Dark Focus',
#  'Chillstic',
#  ' Smerling Adames',
#  'Wolf Schranze',
#  'Sleep Miracle',
#  'Inan',
#  ' chylies',
#  ' pandora.',
#  'A Big Enough Sky',
#  'The Quiet Path',
#  ' The Slumbering One',
#  'Kazuma Okabayashi',
#  '331Music',
#  'Oxford Deluxe Noise',
#  'ambient graffiti',
#  'SerenitySounds',
#  'Mindful Measures',
#  'LUNIQ.',
#  ' Retland',
#  'Piano Peace',
#  'The Slumbering One',
#  'Foam and Sand',
#  ' Robot Koch',
#  ' TWO LANES',
#  'Baby Beethoven',
#  'Dylan Charbeneau',
#  'Eyolf',
#  'Jordin McCullen',
#  'Hania Norman',
#  'Antarctic Wastelands',
#  ' Ether Valley',
#  'Mosaic',
#  'Relaxation Labs',
#  ' AstroPilot',
#  'beef',
#  'Sensitizer',
#  'Binaural Beats Sleep',
#  'Sleepy John',
#  'Ksawery Antol',
#  'Binaural Slaapmuziek',
#  ' Binaural Tidur',
#  ' Binaural Música Para Sono Profundo',
#  'MC Virgins',
#  ' wonder',
#  'Kacey Musgraves',
#  'Dbangz',
#  'JOY.',
#  'Big Gay',
#  'Shiki-TMNS',
#  ' Kodama Boy',
#  ' Big Gay',
#  'Public Theatre',
#  'SahBabii',
#  ' Yun Head',
#  'Within Destruction',
#  'LIGHTSUNZAYN',
#  'Ankhal',
#  'Adry HA',
#  'Kubusiowy',
#  'nobigdyl.',
#  ' D-Real',
#  ' Hentai Dude',
#  'Cole Harris',
#  'Matteo Bocelli',
#  'Greg Maroney',
#  'Charlie Curtis-Beard',
#  ' Akintoye',
#  'Negative XP',
#  'Mom Jeans.',
#  'A-bug',
#  'ovg!',
#  'Lulsnake',
#  'Jafiki',
#  'Kenz',
#  'bedfashion',
#  'Omar Sanchez',
#  'Kid Fresco',
#  'Simon Chylinski',
#  'All$tar',
#  'Mari Ferrari',
#  'GameboyJones',
#  ' None Like Joshua',
#  ' Geno Five',
#  ' Mir Blackwell',
#  ' Zach B',
#  ' Callon B',
#  ' Delta Deez',
#  ' DA-WOLF',
#  ' IAMCHRISCRAIG',
#  ' Jamar Rose',
#  ' FrivolousShara',
#  'Alon Baby',
#  'JC Maverick',
#  ' Marvodagreat',
#  '5L',
#  'Candy Valkyries',
#  'Flamingosis',
#  'Alan Aztec',
#  ' Tonpachi',
#  'Klaus Veen',
#  'Ernesto.',
#  '954mari',
#  ' Jhbboss',
#  ' BlvkDivmonds',
#  ' Connor Quest!',
#  ' Shwabadi',
#  ' Ham Sandwich',
#  ' DizzyEight',
#  ' Mix Williams',
#  'LUCKY TAPES',
#  '666FUCKTHECOPS',
#  'Denzel Curry',
#  'Venom',
#  'Graveland',
#  'Metallica',
#  'Dark Funeral',
#  'Catherine Wheel',
#  'Mgła',
#  'Nargaroth',
#  'Reverend Beat-Man',
#  ' Izobel Garcia',
#  'Mutiilation',
#  'Emperor',
#  'Lich King',
#  'Xasthur',
#  'Ouija Macc',
#  ' Golden Bsp',
#  ' Merkules',
#  'My Morning Jacket',
#  'Pigeon Pit',
#  'Blade and Bath',
#  'Wayfarer',
#  'Vader',
#  ' Bart Krysiuk',
#  'Dimmu Borgir',
#  'Aara',
#  'Urgehal',
#  '1349',
#  'Behexen',
#  'Asagraum',
#  'Metalocalypse: Dethklok',
#  'Max Jury',
#  'Nattefrost',
#  'Sprain',
#  'Enslaved',
#  'Mayhem',
#  'Witch Club Satan',
#  'Nocturnal Depression',
#  'Sabbat',
#  'E the profit',
#  'Mark Lavengood',
#  ' Billy Strings',
#  'Flatt & Scruggs',
#  'Yestalgia',
#  ' Loafy Building',
#  'Joe Maphis',
#  'The Soggy Bottom Boys',
#  ' Dan Tyminski',
#  'Patty Stoneman',
#  'Bill Monroe & His Blue Grass Boys',
#  'Ian Munsick',
#  'Betty Jean Robinson',
#  'Quadry',
#  'Rose Lee Maphis',
#  'Jonathan Hutcherson',
#  'Josh Graves',
#  'Trixie Mattel',
#  'Benny Martin',
#  ' Josh Graves',
#  "Cap'n Jazz",
#  'The Stonemans',
#  'The Hip Abduction',
#  ' Greensky Bluegrass',
#  ' phoffman',
#  'Carl Story',
#  'Cyber Chords',
#  'The Bluegrass Cardinals',
#  'c@m',
#  ' Matty T',
#  'Anne Wilson',
#  'Jim & Jesse',
#  'Luke Trimble',
#  'Bluegrass Worship Band',
#  'The Grandpa Jones & Family',
#  'Matt Phillips',
#  ' Phil Harmonic',
#  'Greensky Bluegrass',
#  'Junior Sisk',
#  ' Joe Mullins',
#  'Legendary Shack Shakers',
#  'Don Reno',
#  'Russell Moore & IIIrd Tyme Out',
#  'ConcernedApe',
#  'The Osborne Brothers',
#  'Mac Wiseman',
#  ' The Osborne Brothers',
#  'Faithless',
#  'Alison Brown',
#  ' Steve Martin',
#  ' Sam Bush',
#  ' Stuart Duncan',
#  ' Trey Hensley',
#  ' Todd Phillips',
#  'Moonbeau',
#  'Big Bud',
#  'Molly Tuttle',
#  ' Molly Tuttle & Golden Highway',
#  'Blues Traveler',
#  'ScHoolboy Q',
#  'Vundabar',
#  'Jackson C. Frank',
#  'Hank Williams',
#  ' Jr.',
#  'Alan Jackson',
#  'Nouvelle Marée',
#  'chillpill',
#  ' Lil Picasso',
#  'Blues Clues',
#  'Joe Bonamassa',
#  'Restless Heart',
#  'ZUTOMAYO',
#  'Cedar Walton',
#  'Solar',
#  'Seal',
#  'Terry Callier',
#  'Jeannie Purdue',
#  'Easy Does It',
#  'Zach Bryan',
#  'DerekAlexander',
#  'Shotgun Willy',
#  ' Yung Craka',
#  ' Lucian',
#  ' ANH',
#  'Le Garroueu',
#  'Reed Stricklers',
#  'soho',
#  'Robert Cray',
#  ' The Robert Cray Band',
#  'llwll',
#  'Tanner Adell',
#  'Fase Yoda',
#  "Blue's Clues & You",
#  'LeeHi',
#  'Elton John',
#  'Mac Critter',
#  'Paul Brown',
#  'Olive Amun',
#  'B.B. King',
#  'Rata Blanca',
#  'Pimp Tobi',
#  'A2h',
#  'Johnny Cash',
#  'CG Spinabenz',
#  'アトラスサウンドチーム',
#  'Markul',
#  'Charlie Parker Quartet',
#  'Jix',
#  'Parker McCollum',
#  'bLAck pARty',
#  'Nick Drake',
#  'Lil Tecca',
#  'Stan Getz',
#  'Elvis Presley',
#  'Estopa',
#  'Bossa Nova Jazz',
#  'Shordie Shordie',
#  ' Offset',
#  "C'est pour le sexe",
#  'Billie Eilish',
#  'Minus 8',
#  ' João Gilberto',
#  'Rio Branco',
#  ' Bossanova Covers',
#  ' Antônio Carlos Jobim',
#  'Kash Doll',
#  ' Tee Grizzley',
#  'imcortex',
#  'Bossa Nova Nouveau',
#  'Lawson Rollins',
#  'Bossa Nova Jazz Cafe',
#  'Origami Angel',
#  'Nossa Alma Canta',
#  'Zenon Pereyra',
#  ' Ainda',
#  'Bossa Nova TBM',
#  'Corcovado X',
#  'Laurindo Almeida',
#  ' The Bossa Nova All Stars',
#  'Pierre Pernaut',
#  'Sitti',
#  '9LFE',
#  'Cafe Music BGM channel',
#  'Butterfly Bossa Nova Breakfast Club',
#  ' Bossa Nova Breakfast Club',
#  'The Psychodelics',
#  'Bossa Nova Brazil',
#  ' Bossa Nova Jazz Cafe',
#  ' Bossa Nova Cafe Music',
#  'Alsina',
#  ' Jimanv13',
#  ' C-Jay Prod',
#  'King Hendrick$',
#  'Declan McKenna',
#  '6YNTHMANE',
#  ' RXDXVIL',
#  'Slowboy',
#  ' lucaf.',
#  ' Crazy Mano',
#  'The Knocks',
#  ' Sofi Tukker',
#  'Anar',
#  ' Polaris',
#  'Barbatuques',
#  'Masayoshi Takanaka',
#  'Geoff & Maria Muldaur',
#  'Mc Gw',
#  ' DJ REMIZEVOLUTION',
#  ' Mc Delux',
#  'deadmau5',
#  'MC L da Vinte',
#  ' MC Gury',
#  'Rauw Alejandro',
#  ' Anitta',
#  'pearl',
#  ' fast forward >>',
#  'Antonio Vercetii',
#  'DECAP',
#  ' DJ Damianito',
#  'Intenational Orchestra',
#  'Bob Baldwin',
#  ' Phil Hamilton',
#  ' Ivan Conte',
#  ' Ragan Whiteside',
#  'Bakermat',
#  'Django Reinhardt',
#  'Wriftet EE',
#  'Dj LK da Escócia',
#  ' Tchakabum',
#  ' MC Ryan SP',
#  ' mc jhenny',
#  ' Mc RF',
#  'Chucky73',
#  ' Fetti031',
#  ' MC',
#  'Brazilian Girls',
#  'DYSMANE',
#  'Sublime With Rome',
#  ' Kordhell',
#  'Wire',
#  'Ray Conniff',
#  'RXDXVIL',
#  ' ZWE1HVNDXR',
#  ' NXVERSOUL',
#  "Alison's Halo",
#  'Chimbala',
#  ' Chucky73',
#  'TBT Prod.',
#  'A.M.C',
#  'Earth',
#  ' Wind & Fire',
#  'Pasteboard',
#  'Golden Boy',
#  'Slightly Stoopid',
#  ' DJ Hellnaw',
#  'VANI VERCIA',
#  'NOVA LUXEO8',
#  'DJ Icey',
#  'MIKI',
#  'Rey Raton 01',
#  'DODI XTC',
#  'Purple Groove',
#  'Basswell',
#  'Khoir Wirawinata',
#  'Groove lab',
#  'NP PROJECT',
#  'Panda Dance',
#  ' Panda House',
#  ' Panda Music',
#  'Rahmat Tahalu',
#  ' Demerris',
#  ' Isle Natividad',
#  'ARCHANGELZZ',
#  'Guau',
#  ' CODE BREAKERZ',
#  'DJ Fixx',
#  'Acco',
#  'Breakbeat Kings',
#  'DJ30A',
#  ' Huda Hudia',
#  'Skatch',
#  'Rosper',
#  'E-Z Rollers',
#  'Kontekst',
#  'Rebelly band',
#  ' Breakbeat.id',
#  ' Rizki mulia',
#  'Huda Hudia',
#  ' DJ Fixx',
#  'Data Overload',
#  'Pro the Leader',
#  ' Dopestyle',
#  ' Prostyle',
#  ' American Poets 2099',
#  ' DOL FUNK',
#  'Freeland',
#  'Aidan Baker',
#  'DJ Diva Remix',
#  ' DJ Viral',
#  ' Dj TikTok Viral',
#  ' DJ30A',
#  'ABDEXFEMX',
#  'Sonique',
#  'SLUDGE',
#  'Los Campesinos!',
#  'Traditional',
#  ' City of London Choir',
#  ' Royal Philharmonic Orchestra',
#  ' Hilary Davan Wetton',
#  'Jim Gaffigan',
#  'Mtsg',
#  ' Salazar2Splashy',
#  'John Williams',
#  'Dino Gala',
#  ' grayto',
#  ' Nil',
#  ' The Central Band of The Royal British Legion',
#  ' Captain David Cole',
#  'Eli Fischer',
#  ' Adam Panek',
#  'ThxSoMch',
#  ' Yxng LJ',
#  'Hits Anthem Back Studio',
#  'Bent',
#  'Tion Wayne',
#  ' Russ Millions',
#  ' ArrDee',
#  ' E1 (3x3)',
#  ' ZT (3x3)',
#  ' Bugzy Malone',
#  ' Buni',
#  ' Fivio Foreign',
#  ' Darkoo',
#  'Oddprophet',
#  ' ILLAMAN',
#  'US Army Strings',
#  ' SSG K.C. Armstrong',
#  ' SFC Michael Ford',
#  ' SFC Nathan Sommers',
#  'Weezer',
#  ' The Coldstream Guards Band',
#  'Darlene Canales',
#  'Toby Stevenson',
#  'Toonorth',
#  'Nick Swardson',
#  'Jeremih',
#  '1i1 pimple',
#  ' lil benjiman',
#  'Dark Polo Gang',
#  '42nd Royal Highlanders',
#  'Bernie Clement',
#  'Maya Badian',
#  'Ben Wheatley',
#  'Thumder P',
#  'Yxngxr1',
#  'Momus',
#  "Chris D'Elia",
#  'Random Hand',
#  'Devlin',
#  ' Ed Sheeran',
#  'Samuel Samuel',
#  'Meditation and Sounds',
#  'Seth Staton Watkins',
#  'Rony',
#  'Randy Edelman',
#  'Pete Holmes',
#  'Songfinch',
#  'Hinds',
#  'The Connecticut Patriots Fife and Drum Corps',
#  'Fleisch',
#  'Ollie O',
#  'E.L. Kurtz',
#  'Sam Hui',
#  'Duffy',
#  'Keung To',
#  'China Syndrome',
#  'Matt Mason',
#  'Hins Cheung',
#  'Canto Popular',
#  'Joyce Cheng',
#  'Lenin Ramírez',
#  'Danny Chan',
#  'Banda Los Recoditos',
#  'Candy Lo',
#  'Muerdo',
#  'Panther Chan',
#  'G Sounds',
#  'AGA',
#  'C AllStar',
#  'Leo Ku',
#  'Jacky Cheung',
#  'MC 張天賦',
#  ' MastaMic',
#  'Juno Mak',
#  'Nancy Kwai',
#  'Eason Chan',
#  ' eason and the duo band',
#  'Alan Tam',
#  'Bolis Pupul',
#  ' Gin Lee',
#  'Hacken Lee',
#  'Gin Lee',
#  'JUDE',
#  'Jason Chan',
#  'Kary Ng',
#  'Lowell Lo',
#  'Miriam Yeung',
#  'Jude',
#  'DJ Sneak',
#  'Cajmere',
#  'Paul Johnson',
#  'Pure Dance Mix',
#  'DRAMA',
#  ' DJ Pharris',
#  'Adonis',
#  ' Dajae',
#  'Chicago House Selection',
#  'The Housemaster Boyz',
#  ' The Rude Boy of House',
#  'Aly-Us',
#  'Sven Tasnadi',
#  'John Summit',
#  'Drake',
#  ' Giveon',
#  'Felix Da Housecat',
#  ' Chris Trucher',
#  'Traxman',
#  'Chez Damier',
#  'Mangabey',
#  'DJPJMADEDISTRACK',
#  'Fingers Inc.',
#  'Marshall Jefferson',
#  ' Solardo',
#  'Vince Lawrence',
#  ' Chuck Roberts',
#  'Boo Williams',
#  'Apres',
#  'Pirate Reem',
#  ' Herb',
#  ' Spenzo',
#  ' Louie',
#  'Rob Wegner',
#  'Fast Eddie',
#  ' Steve "Silk" Hurley',
#  'Alinka',
#  'Chip E.',
#  'Robert Miles',
#  'Vince Staples',
#  'Black Sabbath',
#  'Slick Rick',
#  'Children Of Bodom',
#  'CG5',
#  ' Dagames',
#  'Korn',
#  ' Ice Cube',
#  'Billie Chandler',
#  'Emmure',
#  'Billy Thorpe',
#  'The Tone-Gens',
#  'Tinlicker',
#  ' Robert Miles',
#  'Imagine Dragons',
#  'White Zombie',
#  'Arx',
#  'Daniel Simaz',
#  'Justin Bieber',
#  'Claude Debussy',
#  ' Steven Osborne',
#  'Sword',
#  'Chuck Mangione',
#  'Rameses B',
#  'T. Rex',
#  'ShowTime',
#  'Deborah de Luca',
#  'Bob Sinclar',
#  ' Steve Edwards',
#  'David Gravell',
#  'Bernadette Peters',
#  ' Into the Woods Ensemble',
#  ' Original Broadway Cast of Into the Woods',
#  'Caio Ghisi',
#  'Iron Maiden',
#  'Aram Khachaturian',
#  ' Charlene Farrugia',
#  'KUJAN',
#  'Mozzy',
#  'Jason Isbell',
#  'Rob $tone',
#  ' J. Davi$',
#  ' J Spooks',
#  'Sofia Carson',
#  ' Cameron Boyce',
#  ' Booboo Stewart',
#  ' Mitchell Hope',
#  ' Disney',
#  'Tiësto',
#  ' A Boogie Wit da Hoodie',
#  'Cole Swindell',
#  'Toby Fox',
#  ' David Peacock',
#  ' Augustine Mayuga Gonzales',
#  'Afro Lex Tex',
#  'Stray Kids',
#  'Ka$hhh',
#  'Farruko',
#  ' Ky-Mani Marley',
#  'Mickey Valen',
#  ' Joey Myron',
#  'DJ Noiz',
#  ' Donell Lewis',
#  ' Konecs',
#  ' Cessmun',
#  'Red Velvet',
#  'Young Dolph',
#  'Jawga Boyz',
#  'Trey Songz',
#  'All Rain',
#  'n o r m a l',
#  'Sunday Scaries',
#  ' PiCKUPLiNES',
#  'Bakar',
#  'Rayana Jay',
#  'The Brothers Nylon',
#  'Kuma the Third',
#  'EXOA',
#  'Domknowz',
#  'Sleep Recorders',
#  'intime',
#  'AL SHAMI',
#  'Djloborojo',
#  'Ndotspinalot',
#  'Acoustic Activity',
#  'EXO',
#  'GONE.Fludd',
#  'Noah Wood$',
#  'pandora.',
#  ' chillwithme',
#  ' cødy',
#  'wayudance',
#  ' DRAM',
#  ' Denzel Curry',
#  ' Cousin Stizz',
#  'Pacific',
#  'Blacky',
#  'Hensonn',
#  'Oli Silk',
#  'Crush',
#  ' Sik-K',
#  'LAKEY INSPIRED',
#  'Michael Silverman',
#  'John Stanley',
#  'BabyTron',
#  'James Barker Band',
#  'Anthony Amorim',
#  ' Julia Gomez',
#  'Marcin',
#  ' Tim Henson',
#  'Vampire Weekend',
#  'Camille Saint-Saëns',
#  ' Yo-Yo Ma',
#  ' Kathryn Stott',
#  'Mason Williams',
#  '0to8',
#  ' Alice Sara Ott',
#  'Erik Satie',
#  ' Mimosa',
#  'Bad Wolves',
#  ' Lang Lang',
#  'Lullaby Time',
#  'Alstad',
#  'Fartsdump',
#  'Baby Lullaby Academy',
#  ' Bertrand Chamayou',
#  'Rukkus',
#  'Ludwig van Beethoven',
#  ' Paul Lewis',
#  'Funddss',
#  ' Finghin Collins',
#  'X Prod',
#  'Rafael Krux',
#  ' David Krulic',
#  'Franz Liszt',
#  ' Maria-Theresa Freibott',
#  'Moods',
#  'Timmy Trumpet',
#  ' Bassjackers',
#  'Edvard Grieg',
#  ' David Parry',
#  ' London Philharmonic Orchestra',
#  'Mindstarx',
#  'Gucci Mane',
#  'Gustav Holst',
#  'piranyadi',
#  'Oscar Lopez',
#  'Gustav Mahler',
#  'Carrie Bavaro',
#  'Soulja Boy',
#  ' Lil B',
#  'Young Mozart',
#  ' Lydia Munchinsky',
#  'Franc Blanco',
#  'Music For Dogs',
#  ' Music For Dogs Peace',
#  ' Relaxing Puppy Music',
#  ' Calm Pets Music Academy',
#  ' Lily Anne',
#  'Specialteamz',
#  ' Edo. G',
#  ' Jaysaun',
#  ' Slaine',
#  'John Cage',
#  'Mona Iglesias',
#  'Flo Rida',
#  ' David Guetta',
#  'Charli xcx',
#  'Mac Miller',
#  'Nessa Barrett',
#  'Chappell Roan',
#  'ILOVEMAKONNEN',
#  ' Drake',
#  '50 Cent',
#  'Wham!',
#  'Rob Dougan',
#  'Kasabian',
#  'seencj',
#  'Doodie Lo',
#  'Kelsea Ballerini',
#  'Lana Del Rey',
#  'ASAP Preach',
#  'Mickey Mouse',
#  ' Goofy',
#  'Fabiantony',
#  'French Police',
#  'TOKYOPILL',
#  'nicopatty',
#  'Joey Valence & Brae',
#  'USHER',
#  ' Jeezy',
#  'DJ TETEOO',
#  'DM 90',
#  'RSNZ',
#  'Mairee',
#  ' Jacqwell',
#  ' Razztek',
#  'Smash Stereo',
#  'Craig Morgan',
#  'Lil oceans',
#  'Vacations',
#  'Kyol',
#  'Melanie Martinez',
#  'Vente Blaze',
#  'Godard',
#  ' Ziahfyah',
#  'Noizy',
#  'Peppa Pig Stories',
#  'Drew Flamethrower',
#  ' Inikio',
#  'L.O.F.I',
#  'Scapegoat308',
#  'Don Toliver',
#  ' Lil Durk',
#  ' GloRilla',
#  'Malcolm Winters',
#  'FL@$h',
#  'King The Producer',
#  'Rynx',
#  ' Tiny Meat Gang',
#  'Ander',
#  'Gen Hoshino',
#  'John Mulaney',
#  'Bo Burnham',
#  'Autumn!',
#  'Infinity Song',
#  'Nate Bargatze',
#  'Tom Segura',
#  'misa',
#  'Sion',
#  'Jeff Satur',
#  ...]

# %%
pd.Series(unique_artist_list).value_counts()
# Out:
# Billy Raffoul        1
# charlieonnafriday    1
# Luther White         1
# Oliverquint          1
# Gunna                1
#                     ..
#  Burniss Travis      1
#  Common              1
#  Robert Glasper      1
#  ?uestlove           1
#  C3N6                1
# Name: count, Length: 5851, dtype: int64

# %%
# Create a column called "Collaborations" containing "1" if there is more than one artist, else "0"

collab_list = []

def find_collaborations(x):
    if len(x.split(",")) > 1:
        return 1
    else:
        return 0

unique_id_df["Collaborations"] = unique_id_df['artists'].apply(find_collaborations)

# %%
unique_id_df.head(3)
# Out:
#                        id                           name     genre  \
# 0  7kr3xZk4yb3YSZ4VFtg2Qt                       Acoustic  acoustic
# 1  1kJygfS4eoVziBBI93MSYp                       Acoustic  acoustic
# 2  6lynns69p4zTCRxmmiSY1x  Here Comes the Sun - Acoustic  acoustic
#
#                          artists                          album  popularity  \
# 0                  Billy Raffoul                           1975          58
# 1                  Billy Raffoul        A Few More Hours at YYZ          57
# 2  Molly Hocking, Bailey Rushlow  Here Comes the Sun (Acoustic)          42
#
#    duration_ms  explicit  Collaborations
# 0       172199     False               0
# 1       172202     False               0
# 2       144786     False               1

# %%
# Isolate data with collaborations in DataFrame, collab_df

collab_df = unique_id_df[unique_id_df["Collaborations"] == 1]
collab_df.reset_index(drop=True)

collab_df.head(3)
# Out:
#                        id                                           name  \
# 2  6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 4  5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# 7  42qGA2116mkpSAaxzQfjEf                                      Landslide
#
#       genre                            artists  \
# 2  acoustic      Molly Hocking, Bailey Rushlow
# 4  acoustic      Guus Dielissen, Casper Esmann
# 7  acoustic  Guus Dielissen, Andrew Gialanella
#
#                                            album  popularity  duration_ms  \
# 2                  Here Comes the Sun (Acoustic)          42       144786
# 4  My Love Mine All Mine (Acoustic Instrumental)          33       133922
# 7                                      Landslide          29       199222
#
#    explicit  Collaborations
# 2     False               1
# 4     False               1
# 7     False               1

# %%
collab_df['artists'].value_counts()
# Out:
# artists
# Johann Sebastian Bach, Angela Hewitt                            15
# Designer Disguise, Wow That's What I Call Metalcore             13
# New Age, New Age Instrumental Music, New Age 2021                9
# Claude Debussy, Steven Osborne                                   7
# Travis Scott, Bad Bunny, The Weeknd                              6
#                                                                 ..
# Tom Petty, Jeff Lynne, Steve Winwood, Dhani Harrison, Prince     1
# Alana Springsteen, Chris Stapleton                               1
# Guitar Mage, Peacefulness, Harmoniac                             1
# Blake Shelton, Gwen Stefani                                      1
# Putumayo, Giacomo Lariccia                                       1
# Name: count, Length: 1207, dtype: int64

# %%
# Asking for user input

global artist1
artist1 = input("Who is your favorite artist? ")
while artist1 not in unique_artist_list:
    print("Artist not found in database. Please enter another artist.")
    artist1 = input("Who is your favorite artist? ")
# Out:
# Who is your favorite artist?  Taylor Swift

# %%
# Create a new column called "Collaborated with " + user inputted artist

def get_collaborators(x, artist):
    if artist in x.split(","):
        return 1
    else:
        return 0

collab_df["Collaborated with " + artist1] = collab_df.apply(lambda x: get_collaborators(x.artists, artist1), axis=1)
# Out:
# C:\Users\leeso\AppData\Local\Temp\ipykernel_43500\189421491.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   collab_df["Collaborated with " + artist1] = collab_df.apply(lambda x: get_collaborators(x.artists, artist1), axis=1)

# %%
# Create DataFrame, filtered_df, only containing data where the user inputted artist collaborated

global filtered_df
filtered_df = collab_df[collab_df["Collaborated with "+artist1] == 1].reset_index(drop=True)
filtered_df
# Out:
# Empty DataFrame
# Columns: [id, name, genre, artists, album, popularity, duration_ms, explicit, Collaborations, Collaborated with Taylor Swift]
# Index: []

# %%
# Create final DataFrame, output_df, with columns for: (1) the artist the user input collaborated with, (2) no. of collabs with this
# artist, (3) collaboration albums and songs

artists = []
output_df = pd.DataFrame()
albums = {}
names = {}
for i in range(len(filtered_df)):
    entry = filtered_df.loc[i]['artists'].split(",")
    for artist in entry:
        if artist != artist1:
            artist = artist.strip()
            artists.append(artist)
            if artist in albums.keys() and filtered_df.loc[i]['album'] not in albums[artist]:
                albums[artist].append(filtered_df.loc[i]['album'])
            elif artist not in albums.keys():
                albums[artist] = [filtered_df.loc[i]['album']]
            if artist in names.keys() and filtered_df.loc[i]['name'] not in names[artist]:
                names[artist].append(filtered_df.loc[i]['name'])
            elif artist not in names.keys():
                names[artist] = [filtered_df.loc[i]['name']]
output_df['artist'] = pd.Series(artists).value_counts().index
output_df['no. of collabs with '+ artist1] = pd.Series(artists).value_counts().values
output_df['collab albums'] = output_df['artist'].apply(lambda x: albums[x])
output_df['collab (song) names'] = output_df['artist'].apply(lambda x: names[x])

# %%
output_df
# Out:
# Empty DataFrame
# Columns: [artist, no. of collabs with Taylor Swift, collab albums, collab (song) names]
# Index: []

# %% [markdown]
# # 🎉💻🎉
